# %%
#  File: linear_regression_two_varialbes.ipynb
#  ----------------------------
#  This file shows students the fundamental concepts of 
#  machine learing:
#      - loss function
#      - cost function
#      - linear regression
#      - training process

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This function computes the cost to all data:
# ----------------------------------------
# [sum of (theta*x_i+b - y_i)^2] / (2*m) 
# ----------------------------------------
# where our model is theta*x_i+b
# 
# theta: float, slope of the line
# b: float, the point on y axis intersects with the line when x=0
# x: list, containing 21 data points
# y: list, containing 21 data points

# return: float, the sum over all L2 losses of data points divided by 2m

def cost_function(theta, b, x, y):
    return sum ( (theta * x[i] + b - y[i]) ** 2 for i in range(len(x))) / (2 * len(x))

# %%
# You should see 0.20833333333333334
print(cost_function(0.5, 1.5, [1, 2, 3], [1, 2, 3]))
# Out:
# 0.20833333333333334

# %%
# This function returns the partial derivative of L2 loss function with respect to theta: 
# --------------------------------------
# [sum of (theta*x_i+b - y_i)*x_i] / m
# --------------------------------------
# theta: float, slope of the line
# b: float, the point on y axis intersects with the line when x=0
# x: list, containing 21 data points
# y: list, containing 21 data points
# return: float, the derivative of cost function J with respect to theta

def dJ_dtheta(theta, b, x, y):
    return sum((theta * x[i] + b - y[i]) * x[i] for i in range (len(x) )) / (len(x))

# %%
# You should see 0.6666666666666666
print(dJ_dtheta(0.5, 1.5, [1, 2, 3], [1, 2, 3]))
# Out:
# 0.6666666666666666

# %%
# This function returns the partial derivative of L2 loss function with respect to b: 
# --------------------------------------
# [sum of (theta*x_i+b - y_i)] / m
# --------------------------------------
# theta: float, slope of the line
# b: float, the point on y axis intersects with the line when x=0
# x: list, containing 21 data points
# y: list, containing 21 data points
# return: float, the derivative of cost function J with respect to b

def dJ_db(theta, b, x, y):
    return sum((theta * x[i] + b - y[i]) * 1 for i in range (len(x) )) / (len(x))

# %%
# You should see 0.5
print(dJ_db(0.5, 1.5, [1, 2, 3], [1, 2, 3]))
# Out:
# 0.5

# %%
# ---------- DO NOT EDIT THE CODE BELOW THIS LINE ---------- #

# %%
x = [6.1101,5.5277,8.5186,7.0032,5.8598,8.3829,7.4764,8.5781,6.4862,5.0546,5.7107,10.164,5.734,8.4084,5.6407,5.3794,6.3654,5.1301,6.4296,7.0708,6.1891]

# %%
y = [6.592,9.1302,13.662,11.854,6.8233,11.886,4.3483,12,6.5987,3.8166,3.2522,15.505,3.1551,7.2258,0.71618,3.5129,5.3048,0.56077,3.6518,5.3893,3.1386]

# %%
# ---------- Showing your data ---------- #

# %%
plt.scatter(x, y)
axes = plt.gca()
axes.set_xlim([0,12])
axes.set_ylim([0,30])
# Out:
# (0.0, 30.0)

# %%
# ---------- Initialize your theta ---------- #

# %%
theta = -2
b = -1

# %%
# ---------- Initialize your alpha ---------- #

# %%
# TODO: which value is appropriate for an ideal alpha?

# %%
alpha = 0.01

# %%
# ---------- Training process ---------- #

# %%
theta_history = []
b_history = []
cost_history = []
for i in range(110):
   b_history.append(b)    
   theta_history.append(theta)
   cost_history.append(cost_function(theta,b,x,y))

   #G.D
   # non-steepst descent
   #theta = theta - alpha * dJ_dtheta(theta,b,x,y)
   #b = b - alpha * dJ_db(theta,b,x,y)
                         
   # steepest descent
   theta_tmp = theta
   b_temp = b

   theta = theta - alpha * dJ_dtheta(theta_tmp,b_temp,x,y)
   b = b - alpha * dJ_db(theta_tmp,b_temp,x,y)

# %%
# ---------- Theta changes during training process ---------- #

# %%
print(cost_history)
# Out:
# [242.26337731850708, 68.9931113887198, 22.152312544996864, 9.48897457871618, 6.064771484600506, 5.138168530324135, 4.88673823829931, 4.81782692570556, 4.798256370142217, 4.792024731502277, 4.789399693792491, 4.787750336244486, 4.786365446034707, 4.785052761683509, 4.783760308934957, 4.782474037137176, 4.781190147461286, 4.779907612436489, 4.778626153768843, 4.777345695688515, 4.7760662171740655, 4.774787712004512, 4.773510177960257, 4.772233613903803, 4.7709580189905765, 4.769683392455603, 4.768409733555832, 4.767137041554546, 4.765865315717145, 4.764594555310012, 4.763324759600198, 4.762055927855341, 4.760788059343646, 4.759521153333874, 4.758255209095337, 4.756990225897915, 4.755726203012027, 4.754463139708655, 4.753201035259333, 4.751939888936145, 4.7506797000117365, 4.749420467759289, 4.748162191452552, 4.746904870365817, 4.745648503773934, 4.744393090952289, 4.743138631176836, 4.7418851237240665, 4.740632567871027, 4.739380962895309, 4.738130308075056, 4.736880602688958, 4.735631846016249, 4.734384037336717, 4.733137175930692, 4.7318912610790544, 4.730646292063224, 4.7294022681651695, 4.72815918866741, 4.7269170528530005, 4.725675860005545, 4.724435609409189, 4.723196300348626, 4.721957932109086, 4.720720503976347, 4.719484015236728, 4.718248465177086, 4.717013853084827, 4.71578017824789, 4.714547439954759, 4.713315637494459, 4.712084770156549, 4.710854837231133, 4.709625838008852, 4.708397771780885, 4.707170637838952, 4.705944435475308, 4.704719163982742, 4.703494822654586, 4.702271410784709, 4.701048927667507, 4.6998273725979205, 4.698606744871427, 4.697387043784028, 4.696168268632267, 4.69495041871322, 4.693733493324504, 4.692517491764251, 4.691302413331142, 4.690088257324389, 4.688875023043728, 4.687662709789433, 4.6864513168623025, 4.685240843563678, 4.684031289195419, 4.68282265305992, 4.681614934460107, 4.680408132699431, 4.679202247081873, 4.677997276911948, 4.676793221494692, 4.675590080135668, 4.674387852140972, 4.673186536817223, 4.671986133471567, 4.670786641411676, 4.669588059945747, 4.668390388382507, 4.6671936260311995, 4.665997772201597]

# %%
print()

# %%
theta = theta_history[0]
b = b_history[0]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("0 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: -2, b = -1

# %%
theta = theta_history[1]
b = b_history[1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("1 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: -0.5047546785604766, b = -0.7897318333333334

# %%
theta = theta_history[2]
b = b_history[2]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("2 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.2729145392767073, b = -0.6821178936879169

# %%
theta = theta_history[3]
b = b_history[3]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("3 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.677493579944936, b = -0.6278764226813942

# %%
theta = theta_history[4]
b = b_history[4]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("4 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.8880913667946526, b = -0.6013843050551079

# %%
theta = theta_history[5]
b = b_history[5]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("5 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.9978321872582158, b = -0.5893192882904937

# %%
# ---------- Plot the errors over the training process ---------- #

# %%
plot_x = list(range(len(cost_history)))
plot_y = cost_history
plt.plot(plot_x, plot_y)
plt.title("Errors over iterations", color = 'blue')
# Out:
# Text(0.5, 1.0, 'Errors over iterations')

# %%
if b > 0:
    print(f'############ Final equation: y = {theta_history[-1]}x+{b} ############')
else:
    print(f'############ Final equation: y = {theta_history[-1]}x{b} ############')
# Out:
# ############ Final equation: y = 1.1680791900938172x-0.5893192882904937 ############

# %%
print('############ Lowest Cost for Model [y = 1.0353959032099576x] ############')
print(5.009627415893268)

if b > 0:
    print(f'\n\n ############ Lowest Cost for Model [y={theta_history[-1]}x+{b}] ############ ')
else:
    print(f'\n\n ############ Lowest Cost for Model [y={theta_history[-1]}x{b}] ############ ')
print(cost_history[-1])

if cost_history[-1] < 5.009627415893268:
    print('\n\nYour model won 😆!!!!')
else:
    print('\n\nOops... You lost 😭 Keep trying!!')
# Out:
# ############ Lowest Cost for Model [y = 1.0353959032099576x] ############
# 5.009627415893268
#
#
#  ############ Lowest Cost for Model [y=1.1680791900938172x-0.5893192882904937] ############
# 4.665997772201597
#
#
# Your model won 😆!!!!

# %%
theta = theta_history[-1]
b = b_history[-1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("Final Model", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.1680791900938172, b = -0.9355029453919388
